# %% [markdown]
# # Object Detection
# ## Download Model : YOLOv5

# %%
# clone Project YOLOv5 
# !git clone https://github.com/ultralytics/yolov5
# %cd /content/yolov5

# %% [markdown]
# # Install Dependencies
# Link: [Project](https://github.com/ultralytics/yolov5)

# %%
# %pip install -qr requirements.txt  # install dependencies

# %%
import torch
from IPython.display import Image  # to display images
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))

# %% [markdown]
# # Exmaple Test

# %% [markdown]
# ### detect.py runs YOLOv5 inference on a variety of sources, downloading models automatically from the latest YOLOv5 release, and saving results to runs/detect. Example inference sources are:
#
# ```
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
## Example Model YoloV5 size image 640x640 , weights yolov5s.pt

# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images

# %%
Image(filename='runs/detect/exp/zidane.jpg', width=600)

# %%
# %cd /content/
# !git clone https://github.com/bluebox-dev/Workshop_Dataset2.git

# %% [markdown]
# # Dashboard Training Wandb

# %%
# %pip install -q wandb
# !wandb login

# %% [markdown]
# ## Create Model Yolov5

# %%
# %cd /content/yolov5
# !python train.py --img 416 --epochs 100 --data data.yaml --cfg ./models/yolov5s.yaml --weights 'yolov5s.pt'

# %% [markdown]
# # Use Model Yolov5

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.2 --source ../Workshop_Dataset2/test/images/cat-82_jpg.rf.c25cfb7e8efb559a7dcdbbc0fc052f2b.jpg

# %%
Image(filename='runs/detect/exp2/cat-82_jpg.rf.c25cfb7e8efb559a7dcdbbc0fc052f2b.jpg', width=600)
